# %%
# some imports
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:100% !important; }</style>"))

# Python ≥3.5 is required
import sys

assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn

assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf

assert tf.__version__ >= "2.0"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# % matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rc('font', size=12)
plt.rc('figure', figsize=(12, 5))

# Settings for the visualizations
#import seaborn as sns
#sns.set_style("whitegrid")
#sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import pandas as pd

pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 50)

# Ignore useless warnings (see SciPy issue #5998)
import warnings

warnings.filterwarnings(action="ignore", message="^internal gelsd")
# Others
import cv2
import tqdm
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import train_test_split
from skimage.io import imread
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
#  ## Import data

# %%
# Paths
X_train_path = './dataset/train/train/train/'
X_test_path = './dataset/test/test/test/'
dataset_csv = './dataset/train.txt'
dataset_train = './dataset/train/train'
dataset_test = './dataset/test/test'

# %%
_STOP = 20000


def preprocess(img_paths, dataset_path, preprocess_img_method=None):
    print("loading data")
    data = []
    stop = 0
    for img_path in tqdm.tqdm(img_paths):
        path = os.path.realpath(os.path.join(dataset_path, img_path[1:]))
        img = imread(path)
        if preprocess_img_method:
            img = preprocess_img_method(img)
        else:
            # img = cv2.resize(img,(224,224),cv2.INTER_AREA)
            img = img / 255.  #normalize
        data.append(img)
        stop += 1
        if (stop == _STOP):
            break
    print("loading data done")
    return data


def preprocess_img_vgg(img):
    return preprocess_input(img)

# %%
df = pd.read_csv(dataset_csv, delimiter='\ ', header=None)
y_train_full = np.array(df[1])[:_STOP]
img_paths = df[0]
X_train_full = preprocess(df[0], dataset_train, preprocess_img_method=None)
X_train_full = np.stack(X_train_full)

# Split dataset
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42, test_size=0.1)
X_train = X_train.astype("float32")
X_valid = X_valid.astype("float32")
y_train = y_train.astype("float32")
y_valid = y_valid.astype("float32")
# Out:
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# loading data
# 100%|██████████| 15000/15000 [00:10<00:00, 1381.49it/s]
# loading data done

# %%
no_classes = np.max(y_train_full) + 1
print(no_classes)
# Out:
# 30

# %%
def root_mean_squared_error(y_true, y_pred):
    y1 = tf.cast(tf.math.argmax(y_pred, axis=-1), tf.float32)
    return tf.sqrt(tf.cast(tf.math.reduce_mean(tf.square(y1 - y_true)), tf.float64))

def metric_root_mean_squared_error(y_true, y_pred):
    y1 = tf.math.argmax(y_true, axis=-1)
    y2 = tf.math.argmax(y_pred, axis=-1)
    return tf.sqrt(tf.cast(tf.math.reduce_mean(tf.square(y1 - y2)), tf.float64))

# %%
def get_uncompiled_model():
    model = tf.keras.models.Sequential()
    # model.add(tf.keras.layers.Flatten(input_shape=[158, 158]))
    # model.add(tf.keras.layers.Dense(512, activation="relu", kernel_initializer="he_normal"))
    # model.add(tf.keras.layers.Dense(512, activation="relu", kernel_initializer="he_normal"))
    # model.add(tf.keras.layers.Dense(256, activation="relu", kernel_initializer="he_normal"))
    # model.add(tf.keras.layers.Dense(256, activation="relu", kernel_initializer="he_normal"))
    # model.add(tf.keras.layers.Dense(64, activation="relu", kernel_initializer="he_normal"))
    # model.add(tf.keras.layers.Dropout(0.4))
    # model.add(tf.keras.layers.Dense(no_classes, activation="softmax"))
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=[158, 158]))
    model.add(tf.keras.layers.Dense(250, activation="relu", kernel_initializer="he_normal"))
    model.add(tf.keras.layers.Dense(150, activation="relu", kernel_initializer="he_normal"))
    model.add(tf.keras.layers.Dense(50, activation="relu", kernel_initializer="he_normal"))
    model.add(tf.keras.layers.Dropout(0.4))
    model.add(tf.keras.layers.Dense(no_classes + 1, activation="softmax"))
    return model


def get_compiled_model():
    model = get_uncompiled_model()
    model.compile(
        # optimizer=keras.optimizers.SGD(lr=1e-5, decay=(5 * 1e-5), momentum=0.95),  # Optimizer
        optimizer=keras.optimizers.SGD(),  # Optimizer
        # Loss function to minimize
        loss=tf.keras.losses.SparseCategoricalCrossentropy(),
        # List of metrics to monitor
        metrics=["accuracy", root_mean_squared_error]
    )
    return model

# %%
# Prepare a directory to store all the checkpoints.
checkpoint_dir = "./ckpt/mcc-2-simple"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)


def make_or_restore_model():
    # Either restore the latest model, or create a fresh one
    # if there is no checkpoint available.
    checkpoints = [checkpoint_dir + "/" + name for name in os.listdir(checkpoint_dir)]

    if checkpoints:
        latest_checkpoint = max(checkpoints, key=os.path.getctime)
        print("Restoring from", latest_checkpoint)
        return keras.models.load_model(latest_checkpoint)
    print("Creating a new model")
    return get_compiled_model()


def restore_model():
    checkpoints = [checkpoint_dir + "/" + name for name in os.listdir(checkpoint_dir)]
    if checkpoints:
        latest_checkpoint = max(checkpoints, key=os.path.getctime)
        print("Restoring from", latest_checkpoint)
        return keras.models.load_model(latest_checkpoint)


def restore_model_weights_only():
    model = get_compiled_model()
    # checkpoints = [checkpoint_dir + "/" + name for name in os.listdir(checkpoint_dir)]
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    print("Restoring from", latest)
    model.load_weights(latest)
    return model


def restore_model_weights_only_uncompiled():
    model = get_uncompiled_model()
    # checkpoints = [checkpoint_dir + "/" + name for name in os.listdir(checkpoint_dir)]
    latest = tf.train.latest_checkpoint(checkpoint_dir)
    print("Restoring from", latest)
    model.load_weights(latest)
    return model


### Early Stopping
from tensorflow.keras.callbacks import EarlyStopping

# configure early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=25)
###

### init callbacks
callbacks = [
    keras.callbacks.ModelCheckpoint(
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_loss` score has improved.
        # The saved model name will include the current epoch.
        filepath=checkpoint_dir + "/ckpt_{epoch}_loss={loss:.4f}_val_loss={val_loss:.4f}",
        save_best_only=True,  # Only save a model if `val_loss` has improved.
        monitor="val_loss",
        save_weights_only=True,
        mode="min",
        verbose=1,
    ),
    early_stopping
]

# %%
model = get_compiled_model()
model.summary()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-0.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-0.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-1.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-1.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-2.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-2.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'momentum' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_24 (Flatten)         (None, 24964)             0
# _________________________________________________________________
# dense_96 (Dense)             (None, 250)               6241250
# _________________________________________________________________
# dense_97 (Dense)             (None, 150)               37650
# _________________________________________________________________
# dense_98 (Dense)             (None, 50)                7550
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_99 (Dense)             (None, 31)                1581
# =================================================================
# Total params: 6,288,031
# Trainable params: 6,288,031
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = restore_model_weights_only_uncompiled()
model.compile(
    # optimizer=keras.optimizers.SGD(lr=1e-5, decay=(5 * 1e-5), momentum=0.95),  # Optimizer
    optimizer=keras.optimizers.SGD(lr=5e-4, decay=(5 * 1e-5), momentum=0.95),  # Optimizer
    # Loss function to minimize
    loss=tf.keras.losses.SparseCategoricalCrossentropy(),
    # List of metrics to monitor
    metrics=["accuracy", root_mean_squared_error]
)
# Out:
# Restoring from ./ckpt/mcc-2-simple\ckpt_20_loss=1.9509_val_loss=1.8287

# %%
print("Fit model on training data")
history = model.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=50,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    # validation_data=(X_valid, y_valid),
    validation_split=0.2,
    shuffle=True,
    callbacks=callbacks
)
pd.DataFrame(history.history).plot(figsize=(8, 5))
# Out:
# Fit model on training data
# Epoch 1/50
# 325/338 [===========================>..] - ETA: 0s - loss: 1.9616 - accuracy: 0.2553 - root_mean_squared_error: 12.2196
# Epoch 00001: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9645 - accuracy: 0.2539 - root_mean_squared_error: 12.2234 - val_loss: 2.1705 - val_accuracy: 0.1974 - val_root_mean_squared_error: 12.6402
# Epoch 2/50
# 335/338 [============================>.] - ETA: 0s - loss: 1.9301 - accuracy: 0.2665 - root_mean_squared_error: 12.2136
# Epoch 00002: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9284 - accuracy: 0.2670 - root_mean_squared_error: 12.2119 - val_loss: 2.1144 - val_accuracy: 0.1878 - val_root_mean_squared_error: 12.1456
# Epoch 3/50
# 337/338 [============================>.] - ETA: 0s - loss: 1.9439 - accuracy: 0.2547 - root_mean_squared_error: 12.2230
# Epoch 00003: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9435 - accuracy: 0.2547 - root_mean_squared_error: 12.2203 - val_loss: 1.9369 - val_accuracy: 0.2519 - val_root_mean_squared_error: 11.8502
# Epoch 4/50
# 333/338 [============================>.] - ETA: 0s - loss: 1.9446 - accuracy: 0.2589 - root_mean_squared_error: 12.2099
# Epoch 00004: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9467 - accuracy: 0.2581 - root_mean_squared_error: 12.1978 - val_loss: 2.0929 - val_accuracy: 0.2256 - val_root_mean_squared_error: 11.5978
# Epoch 5/50
# 338/338 [==============================] - ETA: 0s - loss: 1.9490 - accuracy: 0.2629 - root_mean_squared_error: 12.1869
# Epoch 00005: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9490 - accuracy: 0.2629 - root_mean_squared_error: 12.1869 - val_loss: 1.9664 - val_accuracy: 0.2174 - val_root_mean_squared_error: 12.3404
# Epoch 6/50
# 337/338 [============================>.] - ETA: 0s - loss: 1.9276 - accuracy: 0.2608 - root_mean_squared_error: 12.1830
# Epoch 00006: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9270 - accuracy: 0.2613 - root_mean_squared_error: 12.1805 - val_loss: 1.8735 - val_accuracy: 0.2456 - val_root_mean_squared_error: 11.9882
# Epoch 7/50
# 336/338 [============================>.] - ETA: 0s - loss: 1.9339 - accuracy: 0.2658 - root_mean_squared_error: 12.1971
# Epoch 00007: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9362 - accuracy: 0.2651 - root_mean_squared_error: 12.1951 - val_loss: 2.6482 - val_accuracy: 0.1311 - val_root_mean_squared_error: 11.7095
# Epoch 8/50
# 326/338 [===========================>..] - ETA: 0s - loss: 1.9479 - accuracy: 0.2631 - root_mean_squared_error: 12.2011
# Epoch 00008: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9444 - accuracy: 0.2639 - root_mean_squared_error: 12.1926 - val_loss: 1.8780 - val_accuracy: 0.2696 - val_root_mean_squared_error: 12.3534
# Epoch 9/50
# 335/338 [============================>.] - ETA: 0s - loss: 1.9383 - accuracy: 0.2736 - root_mean_squared_error: 12.2224
# Epoch 00009: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9372 - accuracy: 0.2736 - root_mean_squared_error: 12.2181 - val_loss: 2.1064 - val_accuracy: 0.2330 - val_root_mean_squared_error: 11.9699
# Epoch 10/50
# 337/338 [============================>.] - ETA: 0s - loss: 1.9384 - accuracy: 0.2651 - root_mean_squared_error: 12.2142
# Epoch 00010: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9385 - accuracy: 0.2651 - root_mean_squared_error: 12.2127 - val_loss: 2.0227 - val_accuracy: 0.2348 - val_root_mean_squared_error: 12.0135
# Epoch 11/50
# 338/338 [==============================] - ETA: 0s - loss: 1.9245 - accuracy: 0.2716 - root_mean_squared_error: 12.2479
# Epoch 00011: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9245 - accuracy: 0.2716 - root_mean_squared_error: 12.2479 - val_loss: 1.9014 - val_accuracy: 0.2470 - val_root_mean_squared_error: 12.0367
# Epoch 12/50
# 326/338 [===========================>..] - ETA: 0s - loss: 1.9391 - accuracy: 0.2646 - root_mean_squared_error: 12.2486
# Epoch 00012: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9468 - accuracy: 0.2634 - root_mean_squared_error: 12.2308 - val_loss: 2.1739 - val_accuracy: 0.2133 - val_root_mean_squared_error: 12.6827
# Epoch 13/50
# 328/338 [============================>.] - ETA: 0s - loss: 1.9310 - accuracy: 0.2679 - root_mean_squared_error: 12.2045
# Epoch 00013: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9300 - accuracy: 0.2674 - root_mean_squared_error: 12.2140 - val_loss: 1.9667 - val_accuracy: 0.2200 - val_root_mean_squared_error: 12.2031
# Epoch 14/50
# 334/338 [============================>.] - ETA: 0s - loss: 1.9141 - accuracy: 0.2681 - root_mean_squared_error: 12.1836
# Epoch 00014: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9163 - accuracy: 0.2680 - root_mean_squared_error: 12.1885 - val_loss: 2.7079 - val_accuracy: 0.1330 - val_root_mean_squared_error: 11.7438
# Epoch 15/50
# 336/338 [============================>.] - ETA: 0s - loss: 1.9367 - accuracy: 0.2661 - root_mean_squared_error: 12.2082
# Epoch 00015: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9362 - accuracy: 0.2662 - root_mean_squared_error: 12.2063 - val_loss: 2.0408 - val_accuracy: 0.1944 - val_root_mean_squared_error: 12.0577
# Epoch 16/50
# 333/338 [============================>.] - ETA: 0s - loss: 1.9239 - accuracy: 0.2637 - root_mean_squared_error: 12.1986
# Epoch 00016: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9247 - accuracy: 0.2639 - root_mean_squared_error: 12.2039 - val_loss: 1.9291 - val_accuracy: 0.2767 - val_root_mean_squared_error: 12.0802
# Epoch 17/50
# 335/338 [============================>.] - ETA: 0s - loss: 1.9321 - accuracy: 0.2658 - root_mean_squared_error: 12.1914
# Epoch 00017: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9311 - accuracy: 0.2662 - root_mean_squared_error: 12.1924 - val_loss: 2.0352 - val_accuracy: 0.2193 - val_root_mean_squared_error: 12.3202
# Epoch 18/50
# 332/338 [============================>.] - ETA: 0s - loss: 1.9463 - accuracy: 0.2633 - root_mean_squared_error: 12.2226
# Epoch 00018: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9510 - accuracy: 0.2624 - root_mean_squared_error: 12.2141 - val_loss: 2.3320 - val_accuracy: 0.1870 - val_root_mean_squared_error: 11.5764
# Epoch 19/50
# 333/338 [============================>.] - ETA: 0s - loss: 1.9335 - accuracy: 0.2643 - root_mean_squared_error: 12.2279
# Epoch 00019: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9311 - accuracy: 0.2649 - root_mean_squared_error: 12.2244 - val_loss: 1.9299 - val_accuracy: 0.2670 - val_root_mean_squared_error: 12.3868
# Epoch 20/50
# 336/338 [============================>.] - ETA: 0s - loss: 1.9093 - accuracy: 0.2709 - root_mean_squared_error: 12.2384
# Epoch 00020: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9107 - accuracy: 0.2706 - root_mean_squared_error: 12.2359 - val_loss: 1.9768 - val_accuracy: 0.2144 - val_root_mean_squared_error: 12.5268
# Epoch 21/50
# 326/338 [===========================>..] - ETA: 0s - loss: 1.8956 - accuracy: 0.2720 - root_mean_squared_error: 12.2013
# Epoch 00021: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.8943 - accuracy: 0.2715 - root_mean_squared_error: 12.1926 - val_loss: 1.9082 - val_accuracy: 0.2711 - val_root_mean_squared_error: 11.8796
# Epoch 22/50
# 336/338 [============================>.] - ETA: 0s - loss: 1.9478 - accuracy: 0.2683 - root_mean_squared_error: 12.2278
# Epoch 00022: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9477 - accuracy: 0.2684 - root_mean_squared_error: 12.2320 - val_loss: 1.8892 - val_accuracy: 0.2600 - val_root_mean_squared_error: 12.0875
# Epoch 23/50
# 335/338 [============================>.] - ETA: 0s - loss: 1.9032 - accuracy: 0.2684 - root_mean_squared_error: 12.2216
# Epoch 00023: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9022 - accuracy: 0.2688 - root_mean_squared_error: 12.2237 - val_loss: 2.2251 - val_accuracy: 0.1922 - val_root_mean_squared_error: 11.8156
# Epoch 24/50
# 338/338 [==============================] - ETA: 0s - loss: 1.9012 - accuracy: 0.2744 - root_mean_squared_error: 12.1819
# Epoch 00024: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9012 - accuracy: 0.2744 - root_mean_squared_error: 12.1819 - val_loss: 1.9100 - val_accuracy: 0.2411 - val_root_mean_squared_error: 12.1045
# Epoch 25/50
# 332/338 [============================>.] - ETA: 0s - loss: 1.9147 - accuracy: 0.2712 - root_mean_squared_error: 12.2406
# Epoch 00025: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9130 - accuracy: 0.2712 - root_mean_squared_error: 12.2462 - val_loss: 2.2692 - val_accuracy: 0.2141 - val_root_mean_squared_error: 12.3350
# Epoch 26/50
# 328/338 [============================>.] - ETA: 0s - loss: 1.9167 - accuracy: 0.2748 - root_mean_squared_error: 12.1782
# Epoch 00026: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9171 - accuracy: 0.2736 - root_mean_squared_error: 12.1697 - val_loss: 2.0583 - val_accuracy: 0.2089 - val_root_mean_squared_error: 12.0271
# Epoch 27/50
# 327/338 [============================>.] - ETA: 0s - loss: 1.9003 - accuracy: 0.2643 - root_mean_squared_error: 12.1972
# Epoch 00027: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.8989 - accuracy: 0.2651 - root_mean_squared_error: 12.2000 - val_loss: 1.9468 - val_accuracy: 0.2467 - val_root_mean_squared_error: 12.4735
# Epoch 28/50
# 338/338 [==============================] - ETA: 0s - loss: 1.9098 - accuracy: 0.2705 - root_mean_squared_error: 12.2035
# Epoch 00028: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9098 - accuracy: 0.2705 - root_mean_squared_error: 12.2035 - val_loss: 2.1439 - val_accuracy: 0.1996 - val_root_mean_squared_error: 12.3190
# Epoch 29/50
# 328/338 [============================>.] - ETA: 0s - loss: 1.9418 - accuracy: 0.2652 - root_mean_squared_error: 12.2215
# Epoch 00029: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9402 - accuracy: 0.2652 - root_mean_squared_error: 12.2218 - val_loss: 2.0519 - val_accuracy: 0.1907 - val_root_mean_squared_error: 12.1660
# Epoch 30/50
# 336/338 [============================>.] - ETA: 0s - loss: 1.9154 - accuracy: 0.2687 - root_mean_squared_error: 12.2212
# Epoch 00030: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 4ms/step - loss: 1.9140 - accuracy: 0.2694 - root_mean_squared_error: 12.2212 - val_loss: 2.0976 - val_accuracy: 0.2296 - val_root_mean_squared_error: 11.9942
# Epoch 31/50
# 329/338 [============================>.] - ETA: 0s - loss: 1.9290 - accuracy: 0.2655 - root_mean_squared_error: 12.2005
# Epoch 00031: val_loss did not improve from 1.82873
# 338/338 [==============================] - 2s 5ms/step - loss: 1.9285 - accuracy: 0.2656 - root_mean_squared_error: 12.2039 - val_loss: 1.9694 - val_accuracy: 0.2041 - val_root_mean_squared_error: 12.0363

# %%
predict = model.predict(X_train[:1])
predict1 = model.predict(X_train[2][np.newaxis, :, :])
print(predict)
# Out:
# [[2.7371758e-08 1.2714499e-07 7.9844830e-07 2.5785451e-07 5.6970583e-07
#   3.0781959e-07 2.9688763e-08 4.7324932e-08 1.2521253e-06 1.8415471e-05
#   1.2448820e-04 1.6954817e-03 1.0855487e-02 9.3436971e-02 1.1569290e-01
#   3.0096871e-01 2.7902430e-01 9.0469725e-02 7.4870646e-02 3.0672496e-02
#   1.7469306e-03 3.2303610e-04 8.5192405e-05 3.2263042e-06 1.4271055e-06
#   2.8108789e-06 1.2762247e-06 1.7258907e-06 5.9130468e-07 3.2936089e-07
#   3.6685654e-07]]

# %%
preds = []
n = len(y_valid)
for data in X_valid[:n]:
    pred = model.predict(data[np.newaxis, :, :])
    preds.append((np.argmax(pred)))

##
vals = y_valid[:n]
rmse = [np.sqrt(np.sum(np.square(preds - vals)) / n)]
print(rmse)
# Out:
# [2.0250102880397094]

# %%
print(rmse)
# Out:
# [2.138535324312725]

# %% [markdown]
# # Tests

# %%
# Save Model

# %%
model.save('./ckpt/aa2/', save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: ./ckpt/aa2/assets

# %%
model = tf.keras.models.load_model('./ckpt/aa2/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17392/1423402218.py in <module>
# ----> 1 model = tf.keras.models.load_model('./ckpt/aa2/')
#       2
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in load(path, compile, options)
#     119
#     120   model = tf_load.load_internal(
# --> 121       path, options=options, loader_cls=KerasObjectLoader)
#     122
#     123   # pylint: disable=protected-access
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\saved_model\load.py in load_internal(export_dir, tags, options, loader_cls)
#     631       try:
#     632         loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
# --> 633                             ckpt_options)
#     634       except errors.NotFoundError as err:
#     635         raise FileNotFoundError(
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in __init__(self, *args, **kwargs)
#     192     self._models_to_reconstruct = []
#     193
# --> 194     super(KerasObjectLoader, self).__init__(*args, **kwargs)
#     195
#     196     # Now that the node object has been fully loaded, and the checkpoint has
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\saved_model\load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options)
#     128       self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     129
# --> 130     self._load_all()
#     131     self._restore_checkpoint()
#     132
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_all(self)
#     213     # loaded from config may create variables / other objects during
#     214     # initialization. These are recorded in `_nodes_recreated_from_config`.
# --> 215     self._layer_nodes = self._load_layers()
#     216
#     217     # Load all other nodes and functions.
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_layers(self)
#     316
#     317     for node_id, proto in metric_list:
# --> 318       layers[node_id] = self._load_layer(proto.user_object, node_id)
#     319     return layers
#     320
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_layer(self, proto, node_id)
#     341     obj, setter = self._revive_from_config(proto.identifier, metadata, node_id)
#     342     if obj is None:
# --> 343       obj, setter = revive_custom_object(proto.identifier, metadata)
#     344
#     345     # Add an attribute that stores the extra functions/objects saved in the
#
# C:\ProgramData\Anaconda3\envs\tfgpu\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in revive_custom_object(identifier, metadata)
#     844                      'and `from_config` when saving. In addition, please use '
#     845                      'the `custom_objects` arg when calling `load_model()`.'
# --> 846                      .format(identifier))
#     847
#     848
#
# ValueError: Unable to restore custom object of type _tf_keras_metric currently. Please make sure that the layer implements `get_config`and `from_config` when saving. In addition, please use the `custom_objects` arg when calling `load_model()`.

# %%
## TEST restore weights
model = restore_model_weights_only()
# Re-evaluate the model
loss, acc, rmse = model.evaluate(X_valid, y_valid, verbose=2)
print("Restored model, accuracy: {:5.2f}%".format(100 * acc))
print(rmse)
# Out:
# Restoring from ./ckpt\ckpt_47_loss=1.9761_val_loss=1.8614
# 47/47 - 0s - loss: 1.8698 - accuracy: 0.2947 - root_mean_squared_error: 12.2345
# Restored model, accuracy: 29.47%
# 12.234536170959473
